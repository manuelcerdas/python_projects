# %% [markdown]
# First I'm going to read the map as a JSON

# %%
import json

with open ("Cantonal.geojson") as f:
    data = json.load (f)

# %%
aux = data["features"][1]
# Out:
# {'type': 'Feature',
#  'properties': {'gmlid': 'limitecantonal_5k.2',
#   'cod_catalo': '160104',
#   'cod_canton': 607,
#   'canton': 'Golfito',
#   'ori_toponi': 'Se debe  a la forma que presenta el litoral, de un golfo peque̱o, dentro del golfo Dulce',
#   'area': 1753.42,
#   'cod_provin': 6,
#   'provincia': 'Puntarenas',
#   'version': '20201222'},
#  'bbox': [-83.65251302, 8.04024576, -82.88608043, 8.81477668],
#  'geometry': {'type': 'MultiPolygon',
#   'coordinates': [[[[-83.46678258, 8.68886017],
#      [-83.46676787, 8.68885771],
#      [-83.46674713, 8.68886754],
#      [-83.46672386, 8.68887184],
#      [-83.46669788, 8.68886927],
#      [-83.46667309, 8.68885739],
#      [-83.46665266, 8.68884471],
#      [-83.46663223, 8.68883211],
#      [-83.46661017, 8.68881454],
#      [-83.46658132, 8.68878095],
#      [-83.46656935, 8.68876149],
#      [-83.4665564, 8.68873625],
#      [-83.46654889, 8.68871227],
#      [-83.4665451, 8.68868822],
# ...
